# %% [markdown]
# # MUSIC (MUltiple SIgnal Classification) Notebook

# %% [markdown]
# The MUSIC (MUltiple SIgnal Classification) algorithm is a rather generic and well-know algorithm in signal process used for the detection of multiple waves within an array of sensors [Schmidt, 1986].  MUSIC was originally used in SuperDARN by Samson et al. [1990] and Bristow et al. [1994] for the estimation of the characteristics of Medium Scale Traveling Ionospheric Disturbances (MSTIDs) detected by SuperDARN Radars.  These papers have inspired this implementation of the MUSIC algorithm.
#
# While this code has been written with SuperDARN detected MSTIDs in mind, it may be useful for working with other wave-like perturbations moving across the field of view of some geophysical instrument.
#
# This notebook demonstrates the use of the DaViTPy MUSIC module for MSTID parameter estimation.
#
# The DaViTPy MUSIC module is used by creating a musicArray object, which includes built-in methods for keeping track of all steps in the processing algorithm.  As the data is processed, all preceeding variants of the data are saved within the object and a history is created.  This makes it very easy to see what has been done with the data at any step along the way.
#
# *Written by N.A. Frissell, 4 November 2013.*

# %% [markdown]
# **References**
#
# Bristow, W. A., R. A. Greenwald, and J. C. Samson (1994), Identification of high-latitude acoustic gravity wave sources using the Goose Bay HF Radar, J. Geophys. Res., 99(A1), 319–331, doi:10.1029/93JA01470.
#
# Samson, J. C., R. A. Greenwald, J. M. Ruohoniemi, A. Frey, and K. B. Baker (1990), Goose Bay radar observations of Earth-reflected, atmospheric gravity waves in the high-latitude ionosphere, J. Geophys. Res., 95(A6), 7693–7709, doi:10.1029/JA095iA06p07693.
#
# Schmidt, R.O., "Multiple emitter location and signal parameter estimation," Antennas and Propagation, IEEE Transactions on, vol.34, no.3, pp.276,280, Mar 1986, doi:10.1109/TAP.1986.1143830.

# %%
#Import the modules we need.
import sys 
sys.path.append('/davitpy')
import datetime

from matplotlib import pyplot as plt 
import numpy as np

import pydarn

# %% [raw]
# #This cell just sets some preferences to make the plots look nice.
# font = {'family' : 'sans-serif',
#         'weight' : 'bold',
#         'size'   : 22}
# matplotlib.rc('font', **font)
#
# figure = {'figsize' : '15, 12',
#           'dpi'     : 600}
# matplotlib.rc('figure', **figure)

# %% [markdown]
# # MUSIC Processing Example

# %% [markdown]
# ## Loading Data and Basic Plotting

# %%
#Choose the radar and time of the data that we want to look at.
#Then, connect to the data source using the standard DaViTPy
#pydarn.sdio.radDataOpen() routine.

rad='wal'
sTime = datetime.datetime(2011,5,9,8)
eTime = datetime.datetime(2011,5,9,19)

myPtr = pydarn.sdio.radDataOpen(sTime,rad,eTime=eTime)
# Out:
# Looking locally for fitex files with radcode: wal channel: None
# [Errno 2] No such file or directory: '/sd-data/2011/fitex/wal/'
# There was a problem reading local data, perhaps you are not at VT?
# Will attempt fetching data from remote.
#
# Looking on the remote SFTP server for fitex files
# found
#  fitex data on sftp server
# Concatenating all the files in to one
# cat /tmp/sd/20110509.0801.00.wal.fitex /tmp/sd/20110509.1001.00.wal.fitex /tmp/sd/20110509.1201.00.wal.fitex /tmp/sd/20110509.1401.00.wal.fitex /tmp/sd/20110509.1601.00.wal.fitex /tmp/sd/20110509.1801.00.wal.fitex > /tmp/sd/20110509.080000.20110509.190000.wal.fitex
# rm /tmp/sd/20110509.0801.00.wal.fitex
# rm /tmp/sd/20110509.1001.00.wal.fitex
# rm /tmp/sd/20110509.1201.00.wal.fitex
# rm /tmp/sd/20110509.1401.00.wal.fitex
# rm /tmp/sd/20110509.1601.00.wal.fitex
# rm /tmp/sd/20110509.1801.00.wal.fitex

# %%
# Now create the data object.

# By creating this object, data is taken from the SuperDARN database and rearranged into a numpy.array with
# the shape (Nr Times, Nr Beams, Nr Gates).  Missing data is stored as np.nan.

# By default, this command only loads in data where the ground scatter flag is True.

# The fovModel='GS' indicates to calculate the field-of-view coordinates in using the ground-scatter mapping
# formula.  This is standard when looking at MSTIDs using ground scatter.  See Bristow et al. [1994] for details.
dataObj     = pydarn.proc.music.musicArray(myPtr,fovModel='GS')
# Out:
# reached end of data
#
# reached end of data

# %%
dataObj.active.time
# Out:
# array([datetime.datetime(2011, 5, 9, 8, 1, 0, 19000),
#        datetime.datetime(2011, 5, 9, 8, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 8, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 1, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 9, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 1, 0, 19000),
#        datetime.datetime(2011, 5, 9, 10, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 10, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 1, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 11, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 1, 0, 18000),
#        datetime.datetime(2011, 5, 9, 12, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 12, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 1, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 13, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 1, 0, 18000),
#        datetime.datetime(2011, 5, 9, 14, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 14, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 1, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 15, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 1, 0, 19000),
#        datetime.datetime(2011, 5, 9, 16, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 16, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 1, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 31, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 36, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 17, 59, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 0, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 1, 0, 19000),
#        datetime.datetime(2011, 5, 9, 18, 2, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 3, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 4, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 5, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 6, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 7, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 8, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 9, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 10, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 11, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 12, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 13, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 14, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 15, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 16, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 17, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 18, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 19, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 20, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 21, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 22, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 23, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 24, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 25, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 26, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 27, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 28, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 29, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 30, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 31, 0, 18000),
#        datetime.datetime(2011, 5, 9, 18, 32, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 33, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 34, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 35, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 36, 0, 18000),
#        datetime.datetime(2011, 5, 9, 18, 37, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 38, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 39, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 40, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 41, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 42, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 43, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 44, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 45, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 46, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 47, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 48, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 49, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 50, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 51, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 52, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 53, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 54, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 55, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 56, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 57, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 58, 0, 17000),
#        datetime.datetime(2011, 5, 9, 18, 59, 0, 17000)], dtype=object)

# %%
# We can list all of the data sets stored in this object.  Right now there is only one data set, but
# as we go along, each step of processing will create a new data set.

# Each data set is simply stored as an attribute of the dataObj, but the names of all of the data sets can be
# accessed through the get_data_sets() method.
dataObj.get_data_sets()

# %%
# Information about the data set is saved in it's metadata dictionary.  Some of the information in the metadata
# dictionary is used to control certain plotting and processing variables in this module.

dataObj.DS000_originalFit.printMetadata()

# %%
# The music module also keeps track of each step of processing in using the data set's history attribute.

dataObj.DS000_originalFit.printHistory()

# %%
# The 'active' attribute of dataObj is a reference to the most recently used data set of dataObj.  It is also
# the default data set used by all DaViTPy MUSIC processing and plotting routines.  You can see this command
# produces the same result as the cell above.

dataObj.active.printHistory()

# %%
# We can create an RTI plot and a fan plot from the data we loaded.
# You can see that both range gate and geographic latitude are given on the y-axis, and the solar terminator
# is also shaded in.  The terminator does not go below approximately range gate 10.  This is because the ground
# scatter mapping formula is not defined for close-in range gates.

fig = pydarn.plotting.musicRTI(dataObj)

# %%
# We can also make a fan plot.
plotTime = datetime.datetime(2011,5,9,14)
fig = pydarn.plotting.musicFan(dataObj,time=plotTime)

# %% [markdown]
# ## Data Selection

# %%
# We want to focus on just the data that contains the MSTID we are looking for, so we can apply some limits.

# proc.music.defineLimits() does not actually modify the data, it just marks the data by putting an an entry
# into the dataObj.active.metadata dictionary.  The limits will be applied later.  Right now, you can see
# what data will be eliminated by making a new RTI plot.

pydarn.proc.music.defineLimits(dataObj,gateLimits=[30,45])
fig = pydarn.plotting.musicRTI(dataObj)

# %%
# We also to restrict the amount of time we process.  Before actually running the music algorithm, we
# will be filtering the data using a FIR filter that will eat up data at the beginning and end of the filter.
# We can calculate exactly how much time that will be if we know some of the filter characteristics and
# the time resolution of the data.  This can then be used to give us new start and end times.

# For now, let's say we are going to use a filter with 101 taps and a dataset with 120 s resolution.
numtaps = 101
timeres = 120

#Let's also say that we are interested in the MSTID feature between 1400 and 1600 UT.
sTime_of_interest = datetime.datetime(2011,5,9,14)
eTime_of_interest = datetime.datetime(2011,5,9,16)

#Now calculate the new start and end times...
new_times = pydarn.proc.music.filterTimes(sTime_of_interest, eTime_of_interest, timeres, numtaps)
pydarn.proc.music.defineLimits(dataObj,timeLimits=new_times)

fig = pydarn.plotting.musicRTI(dataObj)

# %%
# Now we apply the limits and replot once more.
# Note that many of the processing routines will automatically call applyLimits() before they
# run the processing algorithm.

dataObj.active.applyLimits()
fig = pydarn.plotting.musicRTI(dataObj)

# %%
# Note that a new data set was created when we applied the limits.
dataObj.get_data_sets()

# %%
# Also note that the history of the new object was updated.
dataObj.active.printHistory()

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Interpolation and Cartesian Coordinates

# %%
# Before we feed into the MUSIC Algorithm, we don't want our data to have any gaps in time or space.
# Let's start by interpolating in space along the beams.
pydarn.proc.music.beamInterpolation(dataObj)

# %%
fig = plt.figure(figsize=(20,10))
ax  = fig.add_subplot(121)
pydarn.plotting.musicPlot.musicFan(dataObj,plotZeros=True,dataSet='originalFit',axis=ax,time=plotTime)
ax  = fig.add_subplot(122)
pydarn.plotting.musicPlot.musicFan(dataObj,plotZeros=True,axis=ax,time=plotTime)

# %%
# We also want to interpolate in time.  timeres=120 [seconds] was set in an earlier cell.
pydarn.proc.music.timeInterpolation(dataObj,timeRes=timeres)

# %%
pydarn.plotting.musicPlot.timeSeriesMultiPlot(dataObj,dataSet='timeInterpolated',dataSet2='beamInterpolated')

# %%
# We also want need to calculate a local cartesian grid for each cell we are going to use.
pydarn.proc.music.determineRelativePosition(dataObj)

# %%
#The black cell marks the center of the array.
fig = pydarn.plotting.plotRelativeRanges(dataObj,time=plotTime)

# %% [markdown]
# ### Filtering

# %%
# Now filter the data.
# numtaps=101 was set in an above cell.  The cutoff_frequencies are in Hz.
filt = pydarn.proc.music.filter(dataObj, numtaps=numtaps, cutoff_low=0.0003, cutoff_high=0.0012)

# %%
# At this point, the data has been filtered and saved to a new data set in dataObj.
# Before we look at the data, let's look at the transfer function and impulse response of the data.

fig = filt.plotTransferFunction(xmax=0.004)
fig = filt.plotImpulseResponse()

# %%
# Let's look at the filtered RTI plot.  We should set autoScale to True since the magnitudes will be much
# lower than the original data.

fig = pydarn.plotting.musicRTI(dataObj,autoScale=True)

# %%
# You can see that the filter already marked off the data that you shouldn't use.
# Just applyLimits() and replot.
dataObj.active.applyLimits()
fig = pydarn.plotting.musicRTI(dataObj,autoScale=True)

# %%
# Look at a fan plot.
fig = pydarn.plotting.musicFan(dataObj,time=plotTime,autoScale=True)

# %% [markdown]
# ### Spectral Analysis

# %%
# We have now run all of the processing needed to feed the data into the spectral analysis and MUSIC.
# Let's print the history just to recap what we have done.
dataObj.active.printHistory()

# %%
# First thing to do is to calculate the FFT of every cell...
pydarn.proc.music.calculateFFT(dataObj)

# %%
# We can look at the spectrum of select cells...
pydarn.plotting.spectrumMultiPlot(dataObj,xlim=(-0.0025,0.0025))
pydarn.plotting.musicPlot.spectrumMultiPlot(dataObj,plotType='magnitude',xlim=(0,0.0025))
pydarn.plotting.musicPlot.spectrumMultiPlot(dataObj,plotType='phase',xlim=(0,0.0025))

# %%
# We can also plot the full spectrum.  Here, every FFT bin contains 16 slices,
# showing the data for each of the 16 radar beams from left to right.
# Range gates are shown on the y-axis.
pydarn.plotting.plotFullSpectrum(dataObj,xlim=(0,0.00175))

# %% [markdown]
# ### MUSIC Processing

# %%
# Calculate the cross-spectral matrix Dlm.
pydarn.proc.music.calculateDlm(dataObj)

# %%
# We can look at the Dlm matrix.  This usually isn't necessary for routine processing, but
# it is good to know where the numbers are going...
pydarn.plotting.plotDlm(dataObj)

# %%
# Now, we finally run detect the horizontal wave numbers.
pydarn.proc.music.calculateKarr(dataObj)

# %%
# We can then plot the final result.
pydarn.plotting.musicPlot.plotKarr(dataObj)

# %%
# Again, we can see all of the history gone into processing this plot.
dataObj.active.printHistory()

# %% [markdown]
# ### Feature/Signal Detection

# %%
# We can use the image processing library in scikit-image to automatically find the peaks representing signals.
pydarn.proc.music.detectSignals(dataObj)
pydarn.plotting.musicPlot.plotKarr(dataObj)

# %%
#All of the parameters connected with these signals is located in the sigDectect attribute.
dataObj.active.sigDetect.info

# %%
# It is possible to manually add a signal peak in.
# All appropriate associated wave parameters will be calculated.
pydarn.proc.music.add_signal(0.013,-0.015,dataObj)
pydarn.plotting.musicPlot.plotKarr(dataObj)

# %%
dataObj.active.sigDetect.info

# %%
#Signals can also be removed from the database.
pydarn.proc.music.del_signal(4,dataObj)
pydarn.plotting.musicPlot.plotKarr(dataObj)

# %%
# To get some insight on how the signal processing algorithm works, we can plot the detected groups.
# You can adjust the threshold and neighborhood keywords on pydarn.proc.music.detectSignals() to tweak
# the autodetection.
pydarn.plotting.plotKarrDetected(dataObj)
