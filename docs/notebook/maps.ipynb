# %% [markdown]
# Mapping utilities and options
# ==
# ***
#
# This notebook illustrate how to map SuperDARN radars and FoVs

# %%
from pydarn.radar import *
from pydarn.plotting import *
from utils import *
import datetime as dt

# %% [markdown]
# ### Plot all radars in AACGM coordinates
# Be patient, this takes a few seconds (so many radars, not to mention the coordinate calculatsions)

# %%
figure(figsize=(15,10))
# Plot map
subplot(121)
m1 = plotUtils.mapObj(boundinglat=30., gridLabels=True, coords='mag')
overlayRadar(m1, fontSize=8, all=True, markerSize=5)
subplot(122)
m2 = plotUtils.mapObj(boundinglat=-30., gridLabels=True, coords='mag')
overlayRadar(m2, fontSize=8, all=True, markerSize=5)
# Out:
# Warning, datetime/dateTime not specified, using current time.
# /tmp/sd/.radars.sqlite not found
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-6d6b6d25dadb> in <module>()
#       3 subplot(121)
#       4 m1 = plotUtils.mapObj(boundinglat=30., gridLabels=True, coords='mag')
# ----> 5 overlayRadar(m1, fontSize=8, all=True, markerSize=5)
#       6 subplot(122)
#       7 m2 = plotUtils.mapObj(boundinglat=-30., gridLabels=True, coords='mag')
#
# /usr/lib64/python2.7/site-packages/davitpy-0.2-py2.7-linux-x86_64.egg/pydarn/plotting/mapOverlay.pyc in overlayRadar(mapObj, codes, ids, names, dateTime, annotate, all, hemi, zorder, markerColor, markerSize, fontSize, xOffset)
#      65         # If all radars are to be plotted, create the list
#      66         if all:
# ---> 67                 codes = NetworkObj.getAllCodes(datetime=dateTime, hemi=hemi)
#      68
#      69         # Define how the radars to be plotted are identified (code, id or name)
#
# /usr/lib64/python2.7/site-packages/davitpy-0.2-py2.7-linux-x86_64.egg/pydarn/radar/radStruct.pyc in getAllCodes(self, datetime, hemi)
#     316
#     317         codes = []
# --> 318         for iRad in xrange( self.nradar ):
#     319             tcod = self.radars[iRad].getSiteByDate(datetime)
#     320             if (tcod) and (self.radars[iRad].status == 1) \
#
# AttributeError: 'network' object has no attribute 'nradar'
# /usr/lib64/python2.7/site-packages/matplotlib-1.4.2-py2.7-linux-x86_64.egg/matplotlib/text.py:52: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if rotation in ('horizontal', None):
# /usr/lib64/python2.7/site-packages/matplotlib-1.4.2-py2.7-linux-x86_64.egg/matplotlib/text.py:54: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif rotation == 'vertical':

# %% [markdown]
# ### Plot all radars in geographic coordinates
# This is a bit faster (but there are still lots of radars)

# %%
figure(figsize=(15,10))
# Plot map
subplot(121)
m1 = plotUtils.mapObj(boundinglat=30., gridLabels=False)
overlayRadar(m1, fontSize=8, all=True, markerSize=5)
subplot(122)
m2 = plotUtils.mapObj(boundinglat=-30., gridLabels=False)
overlayRadar(m2, fontSize=8, all=True, markerSize=5)

# %% [markdown]
# ### Plot a single radar, highlight beams
# Still a bit slow due to aacgm coordinates

# %%
# Set map
figure(figsize=(10,10))
width = 111e3*40
m = plotUtils.mapObj(width=width, height=width, lat_0=60., lon_0=-30, coords='mag')
code = 'bks'
# Plotting some radars
overlayRadar(m, fontSize=12, codes=code)
# Plot radar fov
overlayFov(m, codes=code, maxGate=75, beams=[0,4,7,8,23])
# Out:
# Warning, datetime/dateTime not specified, using current time.
# /tmp/sd/.radars.sqlite not found
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3efd8c0f0575> in <module>()
#       5 code = 'bks'
#       6 # Plotting some radars
# ----> 7 overlayRadar(m, fontSize=12, codes=code)
#       8 # Plot radar fov
#       9 overlayFov(m, codes=code, maxGate=75, beams=[0,4,7,8,23])
#
# /usr/lib64/python2.7/site-packages/davitpy-0.2-py2.7-linux-x86_64.egg/pydarn/plotting/mapOverlay.pyc in overlayRadar(mapObj, codes, ids, names, dateTime, annotate, all, hemi, zorder, markerColor, markerSize, fontSize, xOffset)
#      92         # iterates through radars to be plotted
#      93         for radN in input['vals']:
# ---> 94                 rad = NetworkObj.getRadarBy(radN, input['meth'])
#      95                 if not rad: continue
#      96                 site = rad.getSiteByDate(dateTime)
#
# /usr/lib64/python2.7/site-packages/davitpy-0.2-py2.7-linux-x86_64.egg/pydarn/radar/radStruct.pyc in getRadarBy(self, radN, by)
#     208         """
#     209         found = False
# --> 210         for iRad in xrange( self.nradar ):
#     211             if by.lower() == 'code':
#     212                 for ic in xrange(self.radars[iRad].cnum):
#
# AttributeError: 'network' object has no attribute 'nradar'

# %% [markdown]
# ### Plot a nice view of the mid-latitude radars

# %%
# Set map
fig = figure(figsize=(10,10))
m = plotUtils.mapObj(lat_0=70., lon_0=-60, width=111e3*120, height=111e3*55, coords='mag')
codes = ['wal','fhe','fhw','cve','cvw','hok','ade','adw','bks']
# Plotting some radars
overlayRadar(m, fontSize=12, codes=codes)
# Plot radar fov
overlayFov(m, codes=codes[:-1], maxGate=70)#, fovColor=(.8,.9,.9))
overlayFov(m, codes=codes[-1], maxGate=70, fovColor=(.8,.7,.8), fovAlpha=.5)
fig.tight_layout(pad=2)
rcParams.update({'font.size': 12})

# %% [markdown]
# ### Plot the RBSP mode
# This is sloooooooow...

# %%
# Set map
figure(figsize=(8,8))
lon_0 = -70.
m = plotUtils.mapObj(boundinglat=35., lon_0=lon_0)

# Go through each radar
codes = ['gbr','kap','sas','pgr', \
        'kod','sto','pyk','han', \
        'ksr','cve','cvw','wal', \
        'bks','hok','fhw','fhe', \
        'inv','rkn']
beams = [[3,4,6],[10,11,13],[2,3,5],[12,13,15], \
        [2,3,5],[12,13,15],[0,1,3],[5,6,8], \
        [12,13,15],[0,1,3],[19,20,22],[0,1,3], \
        [12,13,15],[0,1,3],[18,19,21],[0,1,3],\
        [6,7,9],[6,7,9]]
for i,rad in enumerate(codes):
    # Plot radar
    overlayRadar(m, fontSize=12, codes=rad)
    # Plot radar fov
    overlayFov(m, codes=rad, maxGate=75, beams=beams[i])
#savefig('rbsp_beams.pdf')
